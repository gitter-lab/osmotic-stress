# %% [markdown]
# Input:
#        - NoisePCSF-080116_union.sif - The union file from running Noise sweeps with PCSF.
#        - ChasmanNetwork-UndirEdges.txt - The undirected connections in the interactome.
# Output:
#     - input-Network_080116.tsv - Input network for TPS
#     - partialDirectedModel.sif - partial directed model for TPS
#
# Creates a list of all of the undirected edges in the union of PCSF noise sweeps. Then, these undirected edges are deleted in order to create a partial directed model. All the edges in the partial directed model must be in the interactome.

# %% [markdown]
# # Import Libraries

# %%
import os.path
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Import files

# %%
USERPATH = r'/home/dylan/Documents/HDD/Wisconsin/'
NOTEBOOK = r'osmotic-stress/Notebooks/'
FILEPATH = './'
UndirectedPath = '../ChasmanNetwork-DirUndir/ChasmanNetwork-UndirEdges.txt'
#FILEPATH = r'/home/dylan/Documents/HDD/Wisconsin/osmotic-stress/Notebooks/Forest-TPS/'
#UndirectedPath = r'/home/dylan/Documents/HDD/Wisconsin/osmotic-stress/Notebooks/ChasmanNetwork-DirUndir/ChasmanNetwork-UndirEdges.txt'
#obtain file from Noise sweep with PCSF
networkPath = FILEPATH + '_union.sif'
dfNetwork = pd.read_csv(networkPath, sep = ' ', header = None)
dfNetwork.drop(1,1,inplace=True)

#obtain undirected interacome
#UndirectedPath = FILEPATH + 'ChasmanNetwork-UndirEdges.txt'
dfUndirected = pd.read_csv(UndirectedPath, sep = '\t', header = None)

# %% [markdown]
# # Print dataframes to show changes in column headings

# %%
dfNetwork.columns = ['GeneA', 'GeneB']
dfUndirected.columns = ['GeneA', 'GeneB']

print dfUndirected
print dfNetwork
# Out:
#       GeneA    GeneB
# 0   YDR420W  YER118C
# 1   YDR420W  YOR153W
# 2   YDR420W  YHR154W
# 3   YGL209W  YGR014W
# 4   YGL035C  YGR014W
# 5   YGR014W  YLR229C
# 6   YER118C  YGR014W
# 7   YER118C  YJL128C
# 8   YER118C  YNL152W
# 9   YDL117W  YER118C
# 10  YER118C  YOR208W
# 11  YCL027W  YER118C
# 12  YBR023C  YER118C
# 13  YER118C  YER118C
# 14  YER118C  YLR452C
# 15  YER118C  YPR032W
# 16  YER118C  YLR353W
# 17  YER118C  YMR032W
# 18  YER118C  YOR188W
# 19  YCL032W  YER118C
# 20  YAL041W  YER118C
# 21  YER118C  YOR181W
# 22  YER118C  YLR362W
# 23  YDL235C  YIL147C
# 24  YDR388W  YIL147C
# 25  YIL147C  YJR074W
# 26  YHR206W  YIL147C
# 27  YIL147C  YIR004W
# 28  YJL123C  YPR075C
# 29  YCL032W  YPR075C
# 30  YGL209W  YPR075C
# 31  YGL035C  YPR075C
#         GeneA    GeneB
# 0     YJR059W  YPR074C
# 1     YBR160W  YDR239C
# 2     YJR059W  YPR091C
# 3     YNL166C  YPL031C
# 4     YJR059W  YKL064W
# 5     YBR160W  YJL076W
# 6     YLR096W  YNL054W
# 7     YDR054C  YHR205W
# 8     YDR477W  YPR115W
# 9     YBR160W  YNL233W
# 10    YHR183W  YPL031C
# 11    YAR002W  YBR160W
# 12    YDR379W  YPL031C
# 13    YBR160W  YMR291W
# 14    YIL047C  YPL031C
# 15    YHL034C  YJR059W
# 16    YLR248W  YNL074C
# 17    YLR248W  YOR018W
# 18    YGL014W  YJR059W
# 19    YJR059W  YLL029W
# 20    YBR130C  YDR477W
# 21    YBR160W  YCL014W
# 22    YAL031C  YBR160W
# 23    YJR059W  YLR319C
# 24    YBR157C  YJR059W
# 25    YBR270C  YJR059W
# 26    YJR059W  YKL168C
# 27    YHR205W  YNL167C
# 28    YBR287W  YPL031C
# 29    YBL007C  YLR248W
# ..        ...      ...
# 314   YDR477W  YIL044C
# 315   YDR379W  YKL166C
# 316   YLR150W  YPL209C
# 317   YJR059W  YLR257W
# 318   YBR160W  YHR158C
# 319   YIL144W  YJR059W
# 320   YDR422C  YDR477W
# 321   YIR003W  YPL031C
# 322   YBR160W  YEL061C
# 323   YHR158C  YJR059W
# 324   YLR093C  YPL031C
# 325   YER125W  YPR181C
# 326   YLR113W  YMR172W
# 327   YJR059W  YKL146W
# 328   YBR160W  YPR174C
# 329   YBR160W  YDR389W
# 330   YGR167W  YPL031C
# 331   YBR160W  YDR093W
# 332   YER125W  YMR275C
# 333   YCL032W  YDR507C
# 334   YBR160W  YOR372C
# 335   YFL033C  YOR380W
# 336   YDR477W  YER027C
# 337  YFR024CA  YPL031C
# 338   YCR023C  YJR059W
# 339   YOL060C  YPL031C
# 340   YLR113W  YNL167C
# 341   YBR160W  YDR052C
# 342   YBR160W  YIL122W
# 343   YBR160W  YOR208W
#
# [344 rows x 2 columns]

# %% [markdown]
# ## Output to file input network for TPS

# %%
path = FILEPATH + 'input-Network_080116.tsv'
dfNetwork.to_csv(path,  index = False, header = False, sep = '\t')

# %% [markdown]
# # Find all undirected edges in the network, and remove them

# %%
lstIndex = []
count = 0
for index1,row1 in dfUndirected.iterrows(): #iterate through undirected edges
    for index2,row2 in dfNetwork.iterrows(): #iterate through interactome
        if ((row1['GeneA'] == row2['GeneA']) and (row1['GeneB'] == row2['GeneB'])) or ((row1['GeneA'] == row2['GeneB']) and (row1['GeneB'] == row2['GeneA'])):
            print row1
            print row2
            lstIndex.append(index2) #make a list of undirected edges
            count = count + 1

dfNetwork = dfNetwork.drop(dfNetwork.index[lstIndex]) #remove undirected edges

print "\n\n"

print "Number of edges removed: " + str(count)
print "Index of edges removed from PCSF file: \n" + str(lstIndex)
# Out:
# GeneA    YER118C
# GeneB    YJL128C
# Name: 7, dtype: object
# GeneA    YER118C
# GeneB    YJL128C
# Name: 176, dtype: object
# GeneA    YDL117W
# GeneB    YER118C
# Name: 9, dtype: object
# GeneA    YDL117W
# GeneB    YER118C
# Name: 69, dtype: object
# GeneA    YER118C
# GeneB    YOR208W
# Name: 10, dtype: object
# GeneA    YER118C
# GeneB    YOR208W
# Name: 296, dtype: object
# GeneA    YBR023C
# GeneB    YER118C
# Name: 12, dtype: object
# GeneA    YBR023C
# GeneB    YER118C
# Name: 110, dtype: object
# GeneA    YER118C
# GeneB    YLR452C
# Name: 14, dtype: object
# GeneA    YER118C
# GeneB    YLR452C
# Name: 245, dtype: object
# GeneA    YER118C
# GeneB    YOR188W
# Name: 18, dtype: object
# GeneA    YER118C
# GeneB    YOR188W
# Name: 200, dtype: object
# GeneA    YCL032W
# GeneB    YER118C
# Name: 19, dtype: object
# GeneA    YCL032W
# GeneB    YER118C
# Name: 91, dtype: object
# GeneA    YAL041W
# GeneB    YER118C
# Name: 20, dtype: object
# GeneA    YAL041W
# GeneB    YER118C
# Name: 263, dtype: object
# GeneA    YER118C
# GeneB    YOR181W
# Name: 21, dtype: object
# GeneA    YER118C
# GeneB    YOR181W
# Name: 122, dtype: object
#
#
#
# Number of edges removed: 9
# Index of edges removed from PCSF file:
# [176, 69, 296, 110, 245, 200, 91, 263, 122]

# %% [markdown]
# # Run Code a Second time to make sure that all undirected edges were removed

# %%
count = 0
for index1,row1 in dfUndirected.iterrows():
    for index2,row2 in dfNetwork.iterrows():
        if ((row1['GeneA'] == row2['GeneA']) and (row1['GeneB'] == row2['GeneB'])) or ((row1['GeneA'] == row2['GeneB']) and (row1['GeneB'] == row2['GeneA'])):
            print row1
            print row2
            lstIndex.append(index2)
            count = count + 1

print "Number of edges found to be undirected: " + str(count)
# Out:
# Number of edges found to be undirected: 0

# %% [markdown]
# ## Create partial Directed Model file

# %%
class Edge:
    def __init__(self):
        self.GeneA = ""
        self.GeneB = ""

    def EdgeExists(self, Network):
        for edge in Network:
            if edge.GeneA == self.GeneA and edge.GeneB == self.GeneB:
                return True
        return False

    def DirectedEdgeExists(self, DirectedNetwork):
        for edge in DirectedNetwork:
            if edge.GeneA == self.GeneA and edge.GeneB == self.GeneB:
                print "Found in Directed Network"
                print "FoundA: " + self.GeneA + ": " + edge.GeneA
                print "FoundB: " + self.GeneB + ": " + edge.GeneB
                return True    
            elif edge.GeneB == self.GeneA and edge.GeneA == self.GeneB:
                print "Found in Directed Network Flipped"
                temp = self.GeneA
                self.GeneA = self.GeneB
                self.GeneB = temp
                print "FoundA: " + self.GeneA + ": " + edge.GeneA
                print "FoundB: " + self.GeneB + ": " + edge.GeneB
                return True
        return False

    def outputEdge(self, f):
        f.write(self.GeneA + "\t")
        f.write("N" + "\t")
        f.write(self.GeneB + "\n")

# %%
DirectedPath = '../ChasmanNetwork-Dir/ChasmanNetwork-Dir.txt'

# used to check whether any edges appear A->B and B->A in the directed network
sortedEdgeSet = set()

print('Removing duplicate directed edges:')
with open(DirectedPath, "r") as f:
    DirectedNetwork = []
    for line in f:
        newEdge = Edge()
        elements = line.strip("\n").split("\t")
        newEdge.GeneA = elements[0]
        newEdge.GeneB = elements[1]
        if(newEdge.EdgeExists(DirectedNetwork)):
            print newEdge.GeneA + ": " + newEdge.GeneB
        else:
            DirectedNetwork.append(newEdge)
        # sort A and B to ignore the direction, then add A:B to the set
        sortedEdge = sorted(elements[0:2])
        sortedEdgeSet.add(':'.join(sortedEdge))

print('{} unique directed edges'.format(len(DirectedNetwork)))
assert len(DirectedNetwork) == len(sortedEdgeSet)
# Out:
# Removing duplicate directed edges:
# YHR205W: DOT6TOD6
# 7583 unique directed edges

# %%
duplicates = 0
with open(networkPath, "r") as f:
    partialDirectedNetwork = []
    # iterate over the Steiner forest output and flip edges as needed to match the
    # direction of the original directed network
    for line in f:
        newEdge = Edge()
        elements = line.strip("\n").split()
        newEdge.GeneA = elements[0]
        newEdge.GeneB = elements[2]
        if newEdge.DirectedEdgeExists(DirectedNetwork): #check if undirected edge in directed model list
            if newEdge.EdgeExists(partialDirectedNetwork): #check if directed edge is already in the partialDirectedNetwork
                print edge.GeneA + ": " + newEdge.GeneA
                duplicates += 1
            else: #if in directed list and not in partial model then place into partial model
                partialDirectedNetwork.append(newEdge)
        else:
            print "NOT"

print('Found {} duplicates'.format(duplicates))
# Out:
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YPR074C: YPR074C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR239C: YDR239C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YPR091C: YPR091C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YNL166C: YNL166C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YKL064W: YKL064W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YJL076W: YJL076W
# Found in Directed Network
# FoundA: YLR096W: YLR096W
# FoundB: YNL054W: YNL054W
# Found in Directed Network Flipped
# FoundA: YHR205W: YHR205W
# FoundB: YDR054C: YDR054C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YPR115W: YPR115W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YNL233W: YNL233W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YHR183W: YHR183W
# Found in Directed Network Flipped
# FoundA: YBR160W: YBR160W
# FoundB: YAR002W: YAR002W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YDR379W: YDR379W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YMR291W: YMR291W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YIL047C: YIL047C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YHL034C: YHL034C
# Found in Directed Network
# FoundA: YLR248W: YLR248W
# FoundB: YNL074C: YNL074C
# Found in Directed Network
# FoundA: YLR248W: YLR248W
# FoundB: YOR018W: YOR018W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YGL014W: YGL014W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YLL029W: YLL029W
# Found in Directed Network Flipped
# FoundA: YDR477W: YDR477W
# FoundB: YBR130C: YBR130C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YCL014W: YCL014W
# Found in Directed Network Flipped
# FoundA: YBR160W: YBR160W
# FoundB: YAL031C: YAL031C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YLR319C: YLR319C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YBR157C: YBR157C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YBR270C: YBR270C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YKL168C: YKL168C
# Found in Directed Network
# FoundA: YHR205W: YHR205W
# FoundB: YNL167C: YNL167C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YBR287W: YBR287W
# Found in Directed Network Flipped
# FoundA: YLR248W: YLR248W
# FoundB: YBL007C: YBL007C
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YKL064W: YKL064W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YHR159W: YHR159W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLR096W: YLR096W
# Found in Directed Network Flipped
# FoundA: YHR205W: YHR205W
# FoundB: YFL033C: YFL033C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YHR205W: YHR205W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YNR013C: YNR013C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YMR037C: YMR037C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YML031W: YML031W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YDL173W: YDL173W
# Found in Directed Network Flipped
# FoundA: YLR113W: YLR113W
# FoundB: YCL032W: YCL032W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YML027W: YML027W
# Found in Directed Network
# FoundA: YBL105C: YBL105C
# FoundB: YLR133W: YLR133W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YLL024C: YLL024C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YDR293C: YDR293C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YKL166C: YKL166C
# Found in Directed Network Flipped
# FoundA: YPL209C: YPL209C
# FoundB: YER125W: YER125W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR507C: YDR507C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOR081C: YOR081C
# Found in Directed Network Flipped
# FoundA: YLR096W: YLR096W
# FoundB: YGR009C: YGR009C
# Found in Directed Network Flipped
# FoundA: YKL048C: YKL048C
# FoundB: YGL035C: YGL035C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YGR008C: YGR008C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YMR068W: YMR068W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLR045C: YLR045C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDR153C: YDR153C
# Found in Directed Network Flipped
# FoundA: YKL048C: YKL048C
# FoundB: YIL033C: YIL033C
# Found in Directed Network
# FoundA: YBL105C: YBL105C
# FoundB: YJL095W: YJL095W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YLR146C: YLR146C
# Found in Directed Network Flipped
# FoundA: YKL048C: YKL048C
# FoundB: YJR053W: YJR053W
# Found in Directed Network
# FoundA: YLR248W: YLR248W
# FoundB: YNL267W: YNL267W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YLR133W: YLR133W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDL140C: YDL140C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR217C: YDR217C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YJR059W: YJR059W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YNR047W: YNR047W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YCL014W: YCL014W
# Found in Directed Network Flipped
# FoundA: YPL209C: YPL209C
# FoundB: YER016W: YER016W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YKR100C: YKR100C
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YGR285C: YGR285C
# Found in Directed Network Flipped
# FoundA: YLR248W: YLR248W
# FoundB: YHR031C: YHR031C
# NOT
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YML119W: YML119W
# Found in Directed Network
# FoundA: YLR113W: YLR113W
# FoundB: YLR138W: YLR138W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR348C: YDR348C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YPL269W: YPL269W
# Found in Directed Network
# FoundA: YJL128C: YJL128C
# FoundB: YJR059W: YJR059W
# Found in Directed Network
# FoundA: YJL128C: YJL128C
# FoundB: YLR113W: YLR113W
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YER040W: YER040W
# Found in Directed Network Flipped
# FoundA: YKL048C: YKL048C
# FoundB: YDR477W: YDR477W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YNR039C: YNR039C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YKL168C: YKL168C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YNL058C: YNL058C
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YJR001W: YJR001W
# Found in Directed Network Flipped
# FoundA: YER125W: YER125W
# FoundB: YDL140C: YDL140C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOR083W: YOR083W
# Found in Directed Network
# FoundA: YER125W: YER125W
# FoundB: YHR131C: YHR131C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YER032W: YER032W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR227W: YDR227W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YBR130C: YBR130C
# Found in Directed Network
# FoundA: YER125W: YER125W
# FoundB: YNL271C: YNL271C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YNR016C: YNR016C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDL225W: YDL225W
# NOT
# Found in Directed Network
# FoundA: YLR113W: YLR113W
# FoundB: YLR248W: YLR248W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR130C: YDR130C
# Found in Directed Network Flipped
# FoundA: YJL095W: YJL095W
# FoundB: YDL223C: YDL223C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YOR359W: YOR359W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YJL146W: YJL146W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YEL032W: YEL032W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLR223C: YLR223C
# Found in Directed Network
# FoundA: YKL166C: YKL166C
# FoundB: YPR185W: YPR185W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YML016C: YML016C
# Found in Directed Network
# FoundA: YJL128C: YJL128C
# FoundB: YKL038W: YKL038W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR001C: YDR001C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YGL008C: YGL008C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YPR156C: YPR156C
# Found in Directed Network Flipped
# FoundA: YPL209C: YPL209C
# FoundB: YIR010W: YIR010W
# Found in Directed Network Flipped
# FoundA: YDR477W: YDR477W
# FoundB: YAR014C: YAR014C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YMR273C: YMR273C
# Found in Directed Network
# FoundA: YER125W: YER125W
# FoundB: YOR018W: YOR018W
# Found in Directed Network
# FoundA: YKL166C: YKL166C
# FoundB: YOR028C: YOR028C
# NOT
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YNR013C: YNR013C
# Found in Directed Network
# FoundA: YDR507C: YDR507C
# FoundB: YMR086W: YMR086W
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YOR018W: YOR018W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YIL140W: YIL140W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YJL020C: YJL020C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YJL110C: YJL110C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YOR083W: YOR083W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLL021W: YLL021W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLR219W: YLR219W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YLR018C: YLR018C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YJL020C: YJL020C
# NOT
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDL189W: YDL189W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOL036W: YOL036W
# Found in Directed Network Flipped
# FoundA: YER125W: YER125W
# FoundB: YBL101C: YBL101C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YOR298CA: YOR298CA
# Found in Directed Network Flipped
# FoundA: YLR248W: YLR248W
# FoundB: YDR385W: YDR385W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YPL115C: YPL115C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YMR005W: YMR005W
# Found in Directed Network
# FoundA: YJL095W: YJL095W
# FoundB: YJR092W: YJR092W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDR251W: YDR251W
# Found in Directed Network Flipped
# FoundA: YLR248W: YLR248W
# FoundB: YJL128C: YJL128C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YKR095W: YKR095W
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YER125W: YER125W
# Found in Directed Network Flipped
# FoundA: YKL048C: YKL048C
# FoundB: YDR507C: YDR507C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YPL019C: YPL019C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YDR169C: YDR169C
# Found in Directed Network Flipped
# FoundA: YJL128C: YJL128C
# FoundB: YIL033C: YIL033C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YIL031W: YIL031W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDR208W: YDR208W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YHR164C: YHR164C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YNL104C: YNL104C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YBR028C: YBR028C
# Found in Directed Network Flipped
# FoundA: YBR160W: YBR160W
# FoundB: YAL024C: YAL024C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YPR115W: YPR115W
# Found in Directed Network Flipped
# FoundA: YLR113W: YLR113W
# FoundB: YDL140C: YDL140C
# Found in Directed Network
# FoundA: YFL033C: YFL033C
# FoundB: YHR132WA: YHR132WA
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YML034W: YML034W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YIL107C: YIL107C
# Found in Directed Network Flipped
# FoundA: YDR477W: YDR477W
# FoundB: YDL225W: YDL225W
# Found in Directed Network Flipped
# FoundA: YBR160W: YBR160W
# FoundB: YBR102C: YBR102C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YOR301W: YOR301W
# Found in Directed Network
# FoundA: YKL166C: YKL166C
# FoundB: YLR113W: YLR113W
# Found in Directed Network Flipped
# FoundA: YDR507C: YDR507C
# FoundB: YDL225W: YDL225W
# Found in Directed Network
# FoundA: YBL105C: YBL105C
# FoundB: YOR372C: YOR372C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YHR133C: YHR133C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR097C: YDR097C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YBL047C: YBL047C
# Found in Directed Network Flipped
# FoundA: YJL095W: YJL095W
# FoundB: YBL007C: YBL007C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YPR040W: YPR040W
# Found in Directed Network Flipped
# FoundA: YHR205W: YHR205W
# FoundB: YDR169C: YDR169C
# Found in Directed Network Flipped
# FoundA: YLR096W: YLR096W
# FoundB: YIL044C: YIL044C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOL100W: YOL100W
# Found in Directed Network Flipped
# FoundA: YBR160W: YBR160W
# FoundB: YBL007C: YBL007C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YER048C: YER048C
# Found in Directed Network Flipped
# FoundA: YLR113W: YLR113W
# FoundB: YIR006C: YIR006C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YGL073W: YGL073W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YKL127W: YKL127W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YDR229W: YDR229W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YJR092W: YJR092W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDR505C: YDR505C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YGR188C: YGR188C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YKL064W: YKL064W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YNL102W: YNL102W
# Found in Directed Network Flipped
# FoundA: YBR160W: YBR160W
# FoundB: YBL063W: YBL063W
# NOT
# Found in Directed Network
# FoundA: YFL033C: YFL033C
# FoundB: YNL157W: YNL157W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YOL070C: YOL070C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YJL092W: YJL092W
# Found in Directed Network
# FoundA: YCL032W: YCL032W
# FoundB: YJL128C: YJL128C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLR425W: YLR425W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOL070C: YOL070C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YNR047W: YNR047W
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YGL035C: YGL035C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YPL155C: YPL155C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOR188W: YOR188W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YJR001W: YJR001W
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YHR103W: YHR103W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YNL233W: YNL233W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YER008C: YER008C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YKL062W: YKL062W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YKL127W: YKL127W
# Found in Directed Network Flipped
# FoundA: YPL209C: YPL209C
# FoundB: YIL144W: YIL144W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YJR070C: YJR070C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YOR113W: YOR113W
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YIL033C: YIL033C
# Found in Directed Network Flipped
# FoundA: YER125W: YER125W
# FoundB: YBR290W: YBR290W
# Found in Directed Network
# FoundA: YLR248W: YLR248W
# FoundB: YLR257W: YLR257W
# Found in Directed Network Flipped
# FoundA: YLR096W: YLR096W
# FoundB: YKR100C: YKR100C
# NOT
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YOR028C: YOR028C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YAL038W: YAL038W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YNL321W: YNL321W
# Found in Directed Network Flipped
# FoundA: YPL209C: YPL209C
# FoundB: YLL018C: YLL018C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YNL271C: YNL271C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YCL051W: YCL051W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YDL131W: YDL131W
# Found in Directed Network
# FoundA: YER125W: YER125W
# FoundB: YGR068C: YGR068C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YGL014W: YGL014W
# Found in Directed Network
# FoundA: YPL031C: YPL031C
# FoundB: YPR042C: YPR042C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YER158C: YER158C
# Found in Directed Network
# FoundA: YPL031C: YPL031C
# FoundB: YPR091C: YPR091C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YOL130W: YOL130W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOR315W: YOR315W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YNL101W: YNL101W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YOR110W: YOR110W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YJL070C: YJL070C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YOR083W: YOR083W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YGR159C: YGR159C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YJL070C: YJL070C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YHR149C: YHR149C
# Found in Directed Network
# FoundA: YPL209C: YPL209C
# FoundB: YPR115W: YPR115W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDR169C: YDR169C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YHR073W: YHR073W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YPL209C: YPL209C
# Found in Directed Network Flipped
# FoundA: YLR096W: YLR096W
# FoundB: YGL035C: YGL035C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YGR241C: YGR241C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YNL074C: YNL074C
# Found in Directed Network Flipped
# FoundA: YLR248W: YLR248W
# FoundB: YDR169C: YDR169C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLR319C: YLR319C
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YHR158C: YHR158C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDR001C: YDR001C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLR187W: YLR187W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YLR190W: YLR190W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YKR089C: YKR089C
# Found in Directed Network Flipped
# FoundA: YNR031C: YNR031C
# FoundB: YJL128C: YJL128C
# Found in Directed Network Flipped
# FoundA: YMR291W: YMR291W
# FoundB: YJR059W: YJR059W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YJR091C: YJR091C
# Found in Directed Network
# FoundA: YJL095W: YJL095W
# FoundB: YLR429W: YLR429W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YFR034C: YFR034C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YHR009C: YHR009C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YOR209C: YOR209C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YLL038C: YLL038C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YLR150W: YLR150W
# NOT
# Found in Directed Network Flipped
# FoundA: YBR160W: YBR160W
# FoundB: YBL105C: YBL105C
# Found in Directed Network Flipped
# FoundA: YPL209C: YPL209C
# FoundB: YLR192C: YLR192C
# Found in Directed Network Flipped
# FoundA: YLR248W: YLR248W
# FoundB: YHR131C: YHR131C
# Found in Directed Network Flipped
# FoundA: YLR113W: YLR113W
# FoundB: YLL043W: YLL043W
# Found in Directed Network Flipped
# FoundA: YLR113W: YLR113W
# FoundB: YCL061C: YCL061C
# Found in Directed Network
# FoundA: YLR096W: YLR096W
# FoundB: YNR039C: YNR039C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YGR100W: YGR100W
# Found in Directed Network Flipped
# FoundA: YBR160W: YBR160W
# FoundB: YBR098W: YBR098W
# Found in Directed Network Flipped
# FoundA: YLR248W: YLR248W
# FoundB: YKL168C: YKL168C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDR229W: YDR229W
# Found in Directed Network
# FoundA: YER125W: YER125W
# FoundB: YML111W: YML111W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YCR065W: YCR065W
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YDR172W: YDR172W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR379W: YDR379W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YHL034C: YHL034C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YNL309W: YNL309W
# Found in Directed Network
# FoundA: YLR113W: YLR113W
# FoundB: YMR037C: YMR037C
# NOT
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YER033C: YER033C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YIL107C: YIL107C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YML111W: YML111W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YGR238C: YGR238C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YLR192C: YLR192C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR027C: YDR027C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YJR001W: YJR001W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YJL146W: YJL146W
# Found in Directed Network
# FoundA: YJL095W: YJL095W
# FoundB: YKL168C: YKL168C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YGL023C: YGL023C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YEL032W: YEL032W
# Found in Directed Network
# FoundA: YPL031C: YPL031C
# FoundB: YPL193W: YPL193W
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YGL253W: YGL253W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YJL123C: YJL123C
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YDR443C: YDR443C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YJR092W: YJR092W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YJR033C: YJR033C
# Found in Directed Network Flipped
# FoundA: YLR113W: YLR113W
# FoundB: YBL103C: YBL103C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YER125W: YER125W
# Found in Directed Network
# FoundA: YJL095W: YJL095W
# FoundB: YPL191C: YPL191C
# Found in Directed Network
# FoundA: YLR248W: YLR248W
# FoundB: YNR047W: YNR047W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YDL225W: YDL225W
# Found in Directed Network
# FoundA: YCL032W: YCL032W
# FoundB: YNR031C: YNR031C
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YKL038W: YKL038W
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YGL023C: YGL023C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YKL048C: YKL048C
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YLL043W: YLL043W
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDL117W: YDL117W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YPL124W: YPL124W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YIL033C: YIL033C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YML119W: YML119W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YML118W: YML118W
# NOT
# Found in Directed Network
# FoundA: YLR096W: YLR096W
# FoundB: YLR257W: YLR257W
# Found in Directed Network
# FoundA: YLR248W: YLR248W
# FoundB: YPR091C: YPR091C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDR293C: YDR293C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR293C: YDR293C
# Found in Directed Network
# FoundA: YJL095W: YJL095W
# FoundB: YNL155W: YNL155W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YIR023W: YIR023W
# Found in Directed Network Flipped
# FoundA: YDR477W: YDR477W
# FoundB: YDR293C: YDR293C
# Found in Directed Network
# FoundA: YFL033C: YFL033C
# FoundB: YPL031C: YPL031C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YNL278W: YNL278W
# Found in Directed Network
# FoundA: YDR054C: YDR054C
# FoundB: YNL103W: YNL103W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YNL167C: YNL167C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YIL084C: YIL084C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOR127W: YOR127W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YNR013C: YNR013C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YDL223C: YDL223C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YML117W: YML117W
# Found in Directed Network Flipped
# FoundA: YPL209C: YPL209C
# FoundB: YDR130C: YDR130C
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YIL044C: YIL044C
# Found in Directed Network Flipped
# FoundA: YKL166C: YKL166C
# FoundB: YDR379W: YDR379W
# Found in Directed Network Flipped
# FoundA: YPL209C: YPL209C
# FoundB: YLR150W: YLR150W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YLR257W: YLR257W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YHR158C: YHR158C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YIL144W: YIL144W
# Found in Directed Network Flipped
# FoundA: YDR477W: YDR477W
# FoundB: YDR422C: YDR422C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YIR003W: YIR003W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YEL061C: YEL061C
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YHR158C: YHR158C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YLR093C: YLR093C
# Found in Directed Network
# FoundA: YER125W: YER125W
# FoundB: YPR181C: YPR181C
# Found in Directed Network
# FoundA: YLR113W: YLR113W
# FoundB: YMR172W: YMR172W
# Found in Directed Network
# FoundA: YJR059W: YJR059W
# FoundB: YKL146W: YKL146W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YPR174C: YPR174C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR389W: YDR389W
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YGR167W: YGR167W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR093W: YDR093W
# Found in Directed Network
# FoundA: YER125W: YER125W
# FoundB: YMR275C: YMR275C
# Found in Directed Network Flipped
# FoundA: YDR507C: YDR507C
# FoundB: YCL032W: YCL032W
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YOR372C: YOR372C
# Found in Directed Network
# FoundA: YFL033C: YFL033C
# FoundB: YOR380W: YOR380W
# Found in Directed Network
# FoundA: YDR477W: YDR477W
# FoundB: YER027C: YER027C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YFR024CA: YFR024CA
# Found in Directed Network Flipped
# FoundA: YJR059W: YJR059W
# FoundB: YCR023C: YCR023C
# Found in Directed Network Flipped
# FoundA: YPL031C: YPL031C
# FoundB: YOL060C: YOL060C
# Found in Directed Network
# FoundA: YLR113W: YLR113W
# FoundB: YNL167C: YNL167C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YDR052C: YDR052C
# Found in Directed Network
# FoundA: YBR160W: YBR160W
# FoundB: YIL122W: YIL122W
# Found in Directed Network Flipped
# FoundA: YOR208W: YOR208W
# FoundB: YBR160W: YBR160W
# Found 0 duplicates

# %%
with open(FILEPATH + "partialDirectedModel.sif", "w") as f:
    for edge in partialDirectedNetwork:
        edge.outputEdge(f)
